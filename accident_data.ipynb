# %%
import xarray as xr

# %%
ds = xr.open_dataset('data_point_2.grib', engine='cfgrib')
ds = ds.to_dataframe().reset_index()
# Out:
# skipping corrupted Message
# Traceback (most recent call last):
#   File "c:\Users\zoero\anaconda3\envs\DataScience\lib\site-packages\cfgrib\messages.py", line 273, in itervalues
#     yield self.filestream.message_from_file(file, errors=errors)
#   File "c:\Users\zoero\anaconda3\envs\DataScience\lib\site-packages\cfgrib\messages.py", line 340, in message_from_file
#     return Message.from_file(file, offset, **kwargs)
#   File "c:\Users\zoero\anaconda3\envs\DataScience\lib\site-packages\cfgrib\messages.py", line 96, in from_file
#     codes_id = eccodes.codes_grib_new_from_file(file)
#   File "c:\Users\zoero\anaconda3\envs\DataScience\lib\site-packages\gribapi\gribapi.py", line 409, in grib_new_from_file
#     GRIB_CHECK(err)
#   File "c:\Users\zoero\anaconda3\envs\DataScience\lib\site-packages\gribapi\gribapi.py", line 226, in GRIB_CHECK
#     errors.raise_grib_error(errid)
# ...

# %%
ds.head()
# Out:
# notebook controller is DISPOSED.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
